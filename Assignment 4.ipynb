# %%
import pandas as pd

# %%
df = pd.read_stata('/Users/elifozlem/Downloads/GSS2022 (1).dta')
# Out:
# /var/folders/3v/9l0bb2hd2_d2ps5ff085nm5c0000gn/T/ipykernel_9275/3849592915.py:1: UnicodeWarning:
# One or more strings in the dta file could not be decoded using utf-8, and
# so the fallback encoding of latin-1 is being used.  This can happen when a file
# has been incorrectly encoded by Stata or some other software. You should verify
# the string values returned are correct.
#   df = pd.read_stata('/Users/elifozlem/Downloads/GSS2022 (1).dta')

# %%
first_rows = df.head()
info = df.info()
missing_values = df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3544 entries, 0 to 3543
# Columns: 879 entries, year to wtssnrps_next
# dtypes: category(854), float64(24), int16(1)
# memory usage: 4.2 MB

# %%
print(df.describe())


print(df['adoptus'].describe())
print(df['frndfam'].describe())
# Out:
#                 id      adoptus     clsrltv      frndfam      conhlth  \
# count  3544.000000  2313.000000  957.000000  1044.000000  1147.000000
# mean   1772.535553     2.692607    2.630094     3.198276     3.055798
# std    1023.268418     0.660438    0.934605     1.482385     0.958306
# min       1.000000     1.000000    1.000000     1.000000     1.000000
# 25%     886.750000     3.000000    2.000000     2.000000     3.000000
# 50%    1772.500000     3.000000    3.000000     4.000000     3.000000
# 75%    2658.250000     3.000000    3.000000     4.000000     4.000000
# max    3545.000000     3.000000    4.000000     7.000000     5.000000
#
#           hlthacc1     hlthacc2     hlthacc3     hlthacc4      hlthweb  ...  \
# count  1114.000000  1086.000000  1059.000000  1035.000000  1138.000000  ...
# mean      1.649910     3.097606     3.068933     2.485024     4.127417  ...
# std       0.992997     1.105351     0.767959     1.326897     1.662490  ...
# ...

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['adoptus'].dropna(), kde=True)
plt.title('adoptus')
plt.xlabel('conhlth')
plt.ylabel('hlthacc1')
plt.show()

# Box plot for 'education'
plt.figure(figsize=(10, 5))
sns.boxplot(df['adoptus'].dropna())
plt.title('conhlth')
plt.xlabel('hlthacc1')
plt.show() #dosyadaki isimlerle isimlendirdim s
