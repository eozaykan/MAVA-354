# %%
#lib'leri importladım
import pandas as pd
import matplotlib as plt
#dosyaları okuttum

population = pd.read_csv("/Users/elifozlem/Downloads/population.csv", index_col=0, header=0)
life = pd.read_csv("/Users/elifozlem/Downloads/life expectancy (1).csv", index_col=0, header=0)
gdp = pd.read_csv("/Users/elifozlem/Downloads/gdp_pcap (1).csv", index_col=0, header=0)
population.reset_index(inplace=True)
population.index.name = None  # Remove the name of the index (country)
life.reset_index(inplace=True)
life.index.name = None  # Remove the name of the index (country)
gdp.reset_index(inplace=True)
gdp.index.name = None  # Remove the name of the index (country)
# Print the first few rows of the modified Population data to verify

print("Population data:")
print(population.head())
print("\nLife expectancy data:")
print(life.head())
print("\nGDP per capita data:")
print(gdp.head())


# Reset index and remove the name of the index (country) only for the Population data
# Out:
# Population data:
#        country   1800   1801   1802   1803   1804   1805   1806   1807   1808  \
# 0  Afghanistan  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M
# 1       Angola  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M
# 2      Albania   400k   402k   404k   405k   407k   409k   411k   413k   414k
# 3      Andorra   2650   2650   2650   2650   2650   2650   2650   2650   2650
# 4          UAE  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k
#
#    ...   2091   2092   2093   2094   2095   2096   2097   2098   2099   2100
# 0  ...   108M   108M   109M   109M   109M   110M   110M   110M   111M   111M
# 1  ...   125M   126M   127M   128M   129M   130M   131M   131M   132M   133M
# 2  ...  1.35M  1.32M  1.29M  1.26M  1.23M  1.21M  1.18M  1.15M  1.12M   1.1M
# 3  ...  62.5k  62.2k  61.9k  61.7k  61.4k  61.2k  60.9k  60.7k  60.5k  60.2k
# 4  ...  13.5M  13.5M  13.6M  13.7M  13.8M  13.8M  13.9M    14M    14M  14.1M
#
# ...

# %%
# Out:
# Population columns: Index(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807', '1808',
#        '1809',
#        ...
#        '2091', '2092', '2093', '2094', '2095', '2096', '2097', '2098', '2099',
#        '2100'],
#       dtype='object', length=301)
# Life expectancy columns: Index(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807', '1808',
#        '1809',
#        ...
#        '2091', '2092', '2093', '2094', '2095', '2096', '2097', '2098', '2099',
#        '2100'],
#       dtype='object', length=301)

# %%
#mergeledim

# %%
merged_data = population.merge(life, on="country")


merged_data = merged_data.merge(gdp, on="country")


print("Merged data:")
print(merged_data.head())
# Out:
# Merged data:
#        country 1800_x 1801_x 1802_x 1803_x 1804_x 1805_x 1806_x 1807_x 1808_x  \
# 0  Afghanistan  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M
# 1       Angola  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M
# 2      Albania   400k   402k   404k   405k   407k   409k   411k   413k   414k
# 3      Andorra   2650   2650   2650   2650   2650   2650   2650   2650   2650
# 4          UAE  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k
#
#    ...   2091   2092   2093   2094   2095   2096   2097   2098   2099   2100
# 0  ...   4800   4910   5030   5150   5270   5390   5520   5650   5780   5920
# 1  ...  24.8k  25.3k  25.9k  26.4k  26.9k  27.4k    28k  28.5k  29.1k  29.6k
# 2  ...    54k  54.6k  55.2k  55.8k  56.4k  56.9k  57.5k  58.1k  58.7k  59.2k
# 3  ...  79.3k  79.5k  79.8k  80.1k  80.4k  80.7k    81k  81.2k  81.5k  81.8k
# 4  ...  92.5k  92.6k  92.6k  92.7k  92.8k  92.9k  92.9k    93k  93.1k  93.1k
#
# ...

# %%
#drop missing values
merged_data = merged_data.dropna()

# Print the first few rows of the merged data after dropping missing values
#print("Merged data after dropping missing values:")
#print(merged_data.head())



print(merged_data.columns)
# Out:
# Index(['country', '1800_x', '1801_x', '1802_x', '1803_x', '1804_x', '1805_x',
#        '1806_x', '1807_x', '1808_x',
#        ...
#        '2091', '2092', '2093', '2094', '2095', '2096', '2097', '2098', '2099',
#        '2100'],
#       dtype='object', length=904)

# %%
print("First 5 rows of the dataset:")
print(merged_data.head())

# Display the last 5 rows of the dataset
print("Last 5 rows of the dataset:")
print(merged_data.tail())
# Out:
# First 5 rows of the dataset:
#        country 1800_x 1801_x 1802_x 1803_x 1804_x 1805_x 1806_x 1807_x 1808_x  \
# 0  Afghanistan  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M
# 1       Angola  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M
# 2      Albania   400k   402k   404k   405k   407k   409k   411k   413k   414k
# 4          UAE  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k
# 5    Argentina   534k   520k   506k   492k   479k   466k   453k   441k   429k
#
#    ...   2091   2092   2093   2094   2095   2096   2097   2098   2099   2100
# 0  ...   4800   4910   5030   5150   5270   5390   5520   5650   5780   5920
# 1  ...  24.8k  25.3k  25.9k  26.4k  26.9k  27.4k    28k  28.5k  29.1k  29.6k
# 2  ...    54k  54.6k  55.2k  55.8k  56.4k  56.9k  57.5k  58.1k  58.7k  59.2k
# 4  ...  92.5k  92.6k  92.6k  92.7k  92.8k  92.9k  92.9k    93k  93.1k  93.1k
# 5  ...  59.7k  60.2k  60.8k  61.3k  61.9k  62.4k  62.9k  63.5k    64k  64.5k
#
# ...

# %%
print("\nFirst 5 rows:")
print(merged_data.head())

print("\nLast 5 rows:")
print(merged_data.tail())

data_2000 = merged_data[['country', '2000']]
print("Data for the year 2000:")
print(data_2000)
# Out:
# First 5 rows:
#        country 1800_x 1801_x 1802_x 1803_x 1804_x 1805_x 1806_x 1807_x 1808_x  \
# 0  Afghanistan  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M
# 1       Angola  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M
# 2      Albania   400k   402k   404k   405k   407k   409k   411k   413k   414k
# 4          UAE  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k
# 5    Argentina   534k   520k   506k   492k   479k   466k   453k   441k   429k
#
#    ...   2091   2092   2093   2094   2095   2096   2097   2098   2099   2100
# 0  ...   4800   4910   5030   5150   5270   5390   5520   5650   5780   5920
# 1  ...  24.8k  25.3k  25.9k  26.4k  26.9k  27.4k    28k  28.5k  29.1k  29.6k
# 2  ...    54k  54.6k  55.2k  55.8k  56.4k  56.9k  57.5k  58.1k  58.7k  59.2k
# 4  ...  92.5k  92.6k  92.6k  92.7k  92.8k  92.9k  92.9k    93k  93.1k  93.1k
# 5  ...  59.7k  60.2k  60.8k  61.3k  61.9k  62.4k  62.9k  63.5k    64k  64.5k
#
# ...

# %%
unique_countries = merged_data['country'].unique()
print("\nUnique countries represented in the dataset:")
print(unique_countries)
# Out:
# Unique countries represented in the dataset:
# ['Afghanistan' 'Angola' 'Albania' 'UAE' 'Argentina' 'Armenia'
#  'Antigua and Barbuda' 'Australia' 'Austria' 'Azerbaijan' 'Burundi'
#  'Belgium' 'Benin' 'Burkina Faso' 'Bangladesh' 'Bulgaria' 'Bahrain'
#  'Bahamas' 'Bosnia and Herzegovina' 'Belarus' 'Belize' 'Bolivia' 'Brazil'
#  'Barbados' 'Brunei' 'Bhutan' 'Botswana' 'Central African Republic'
#  'Canada' 'Switzerland' 'Chile' 'China' "Cote d'Ivoire" 'Cameroon'
#  'Congo, Dem. Rep.' 'Congo, Rep.' 'Colombia' 'Comoros' 'Cape Verde'
#  'Costa Rica' 'Cuba' 'Cyprus' 'Czech Republic' 'Germany' 'Djibouti'
#  'Denmark' 'Dominican Republic' 'Algeria' 'Ecuador' 'Egypt' 'Eritrea'
#  'Spain' 'Estonia' 'Ethiopia' 'Finland' 'Fiji' 'France'
#  'Micronesia, Fed. Sts.' 'Gabon' 'UK' 'Georgia' 'Ghana' 'Guinea' 'Gambia'
#  'Guinea-Bissau' 'Equatorial Guinea' 'Greece' 'Grenada' 'Guatemala'
#  'Guyana' 'Hong Kong, China' 'Honduras' 'Croatia' 'Haiti' 'Hungary'
# ...

# %%
for index, country in enumerate(unique_countries):
    print(f"Index: {index}, Country: {country}")
# Out:
# Index: 0, Country: Afghanistan
# Index: 1, Country: Angola
# Index: 2, Country: Albania
# Index: 3, Country: UAE
# Index: 4, Country: Argentina
# Index: 5, Country: Armenia
# Index: 6, Country: Antigua and Barbuda
# Index: 7, Country: Australia
# Index: 8, Country: Austria
# Index: 9, Country: Azerbaijan
# Index: 10, Country: Burundi
# Index: 11, Country: Belgium
# Index: 12, Country: Benin
# Index: 13, Country: Burkina Faso
# Index: 14, Country: Bangladesh
# Index: 15, Country: Bulgaria
# Index: 16, Country: Bahrain
# Index: 17, Country: Bahamas
# Index: 18, Country: Bosnia and Herzegovina
# Index: 19, Country: Belarus
# Index: 20, Country: Belize
# Index: 21, Country: Bolivia
# Index: 22, Country: Brazil
# Index: 23, Country: Barbados
# Index: 24, Country: Brunei
# Index: 25, Country: Bhutan
# Index: 26, Country: Botswana
# Index: 27, Country: Central African Republic
# Index: 28, Country: Canada
# Index: 29, Country: Switzerland
# Index: 30, Country: Chile
# ...

# %%
#last index is 185 so we have 186 unique listed countries
#I don't know how to classify data with continents, so I picked the all ad sorted them using population data on its own.

# %%
population_data = pd.read_csv("/Users/elifozlem/Downloads/population.csv", index_col=0, header=0)
population_data.reset_index(inplace=True)
population_data.index.name = None
print(population_data)
sorted_populations = population_data.iloc[:2].sort_values(by='2100', ascending=False)
print(sorted_populations)
# Out:
#           country   1800   1801   1802   1803   1804   1805   1806   1807  \
# 0     Afghanistan  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M
# 1          Angola  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M
# 2         Albania   400k   402k   404k   405k   407k   409k   411k   413k
# 3         Andorra   2650   2650   2650   2650   2650   2650   2650   2650
# 4             UAE  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k
# ..            ...    ...    ...    ...    ...    ...    ...    ...    ...
# 192         Samoa  47.3k  47.3k  47.3k  47.3k  47.3k  47.3k  47.3k  47.2k
# 193         Yemen  2.59M  2.59M  2.59M  2.59M  2.59M  2.59M  2.59M  2.59M
# 194  South Africa  1.45M  1.45M  1.46M  1.46M  1.47M  1.47M  1.48M  1.49M
# 195        Zambia   747k   758k   770k   782k   794k   806k   818k   831k
# 196      Zimbabwe  1.09M  1.09M  1.09M  1.09M  1.09M  1.09M  1.09M  1.09M
#
#       1808  ...   2091   2092   2093   2094   2095   2096   2097   2098  \
# ...

# %%
#categorizing high-low population (I messed here up and fixed with gpt but didn't work

# %%
def categorize_population(population):
    if pd.isna(population):
        return 'Unknown'
 
    elif isinstance(population, float): #I added this because I had an error with floats and NaN info
        population_numeric = round(population)
    else:

        population_numeric = round(float(population.replace('M', '000000').replace('k', '000')))
    
   
    if population_numeric > high_threshold:
        return 'High'
    elif population_numeric > medium_threshold:
        return 'Medium'
    else:
        return 'Low'
print(population_data)

print(population_data['Population Category'])
# Out:
# 0       111M
# 1       133M
# 2       1.1M
# 3      60.2k
# 4      14.1M
#        ...
# 192     441k
# 193    74.2M
# 194    74.6M
# 195    63.6M
# 196    35.6M
# Name: 2100, Length: 197, dtype: object
